# %% [markdown]
# # Dataset Creation

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import os
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

BASE_SIMULATION_DIR = '../data/simulations/'
BASE_MEASURE_DIR = '../data/measures/'
C = 'consensus_time'
F = 'opinion_change_frequency'

# %% [markdown]
# ## Reading CSV files

# %% [markdown]
# ### Measures

# %%
measures_file_list = []
for network in os.listdir(BASE_MEASURE_DIR):
    df = pd.read_csv(BASE_MEASURE_DIR + network, index_col=0)
    df.insert(0, 'type', network.split('.')[0])
    measures_file_list.append(df)
    
measures_df = pd.concat(measures_file_list)

FEATURES = list(measures_df.columns)

# %%
measures_df = measures_df.rename_axis(['network'])

# %%
measures_df = measures_df[~(measures_df['closeness'].isna())]
FEATURES = list(measures_df.columns)[1:]
measures_df.describe()
# Out:
#        clustering   closeness            n
# count  197.000000  197.000000   197.000000
# mean     0.518071    0.697597  1259.989848
# std      0.279386    0.141018   142.531987
# min      0.019483    0.381968  1013.000000
# 25%      0.299717    0.588160  1146.000000
# 50%      0.518177    0.674908  1269.000000
# 75%      0.766184    0.810564  1387.000000
# max      0.994529    0.994563  1493.000000

# %%
measures_df.to_csv('../data/measures.csv', index=False)

# %% [markdown]
# ### Simulations

# %%
simulations_file_list = []
for network in os.listdir(BASE_SIMULATION_DIR):
    df = pd.read_csv(BASE_SIMULATION_DIR + network, index_col=0, header=[0,1])
    simulations_file_list.append(df)

simulations_df = pd.concat(simulations_file_list)

# %%
simulations_df = simulations_df.stack(level=0, future_stack=True).rename_axis(['network','initialization']).reset_index()

# %%
simulations_df.head()
# Out:
#                     network initialization  consensus_time  \
# 0   erdos_renyi_78.edgelist         random            5.93
# 1  erdos_renyi_100.edgelist         random            6.70
# 2  erdos_renyi_153.edgelist         random           10.20
# 3    erdos_renyi_0.edgelist         random            4.04
# 4  erdos_renyi_151.edgelist         random            4.95
#
#    opinion_change_frequency
# 0                    343.76
# 1                    360.48
# 2                    365.38
# 3                    305.61
# 4                    310.04

# %% [markdown]
# ### Merging and creating the dataset

# %%
dataset = measures_df.merge(simulations_df, on='network', how='inner')

# %%
from sklearn.preprocessing import LabelEncoder
dataset['groups'] = LabelEncoder().fit_transform(dataset['type'])
# dataset.reset_index(inplace=True)

# %%
dataset
# Out:
#                       network         type  clustering  closeness       n  \
# 0     erdos_renyi_78.edgelist  erdos_renyi    0.475252   0.655912  1474.0
# 1    erdos_renyi_100.edgelist  erdos_renyi    0.436546   0.639639  1480.0
# 2    erdos_renyi_153.edgelist  erdos_renyi    0.309121   0.591442  1333.0
# 3      erdos_renyi_0.edgelist  erdos_renyi    0.644705   0.737895  1415.0
# 4    erdos_renyi_151.edgelist  erdos_renyi    0.563176   0.696041  1281.0
# ..                        ...          ...         ...        ...     ...
# 192   erdos_renyi_50.edgelist  erdos_renyi    0.925410   0.930627  1397.0
# 193   erdos_renyi_69.edgelist  erdos_renyi    0.946267   0.949052  1071.0
# 194    erdos_renyi_7.edgelist  erdos_renyi    0.083608   0.521646  1330.0
# 195  erdos_renyi_160.edgelist  erdos_renyi    0.940409   0.943801  1209.0
# 196   erdos_renyi_35.edgelist  erdos_renyi    0.637585   0.734070  1398.0
#
#     initialization  consensus_time  opinion_change_frequency  groups
# 0           random            5.93                    343.76       0
# 1           random            6.70                    360.48       0
# 2           random           10.20                    365.38       0
# 3           random            4.04                    305.61       0
# 4           random            4.95                    310.04       0
# ..             ...             ...                       ...     ...
# 192         random            2.23                    299.40       0
# 193         random            2.08                    246.75       0
# 194         random           42.25                    344.00       0
# 195         random            1.94                    284.21       0
# 196         random            4.17                    320.71       0
#
# [197 rows x 9 columns]

# %%
dataset.to_csv('../data/dataset.csv', index=False)
