# %%
import networkx as nx
import igraph
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('../data/simulations/erdos_renyi.csv', header=0)

# %%
dataset['p'] = dataset['network'].apply(lambda x: float('0.' + x.split('.')[1]))

# %%
dataset.head()
# Out:
#                           network  consensus_time  opinion_change_frequency  \
# 0  erdos_renyi_0_p0.3208.edgelist            7.41                     26.12
# 1  erdos_renyi_1_p0.0246.edgelist          150.00                    263.67
# 2  erdos_renyi_2_p0.4443.edgelist            4.84                     26.34
# 3  erdos_renyi_3_p0.3475.edgelist           11.43                   3167.76
# 4  erdos_renyi_4_p0.3830.edgelist            5.02                     24.22
#
#         p
# 0  0.3208
# 1  0.0246
# 2  0.4443
# 3  0.3475
# 4  0.3830

# %%
sns.scatterplot(x=dataset['p'], y=dataset['consensus_time'])
plt.yscale('log')
plt.xscale('log')
